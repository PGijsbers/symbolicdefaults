# %% [markdown]
# # Symbolic Defaults

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from output_parser import parse_console_output
results = parse_console_output("D:\\data/symb_def_svc_100_20_prog.txt")

# %% [markdown]
# The following plots show the internal fitness score. The internal fitness score is the average of scores predicted by the surrogate model across all tasks except the indicated one.

# %%
print(len(results))
# Out:
# 94

# %%
def plot_result(result, ax):    
    max_score_per_gen = [gen.score_max for gen in result.information_by_generation]
    ax.plot(range(result.n_generations_elapsed), max_score_per_gen)
        ax.set_ylim([0., 1.])
    ax.set_xlim([0, 100])
    ax.set_title(result.task)

# %%
n_rows, n_cols = 20, 5
fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(20, 40), sharey='row')
for i, result in enumerate(results):
    ax = axes[i//n_cols, i % n_cols]
    plot_result(result, ax)
fig.tight_layout()

# %%
axes.shape
# Out:
# (20, 5)

# %% [markdown]
# The top scoring expressions per task. Overall:

# %%
for result in results:
    print(result.task, result.top_five_expressions[0])
# Out:
# 3 p, truediv(mkd, 4.0)
# 6 32.0, truediv(mkd, 4.0)
# 11 truediv(p, mcp), mul(0.22741145537539598, mkd)
# 12 add(truediv(n, p), p), mul(mkd, 0.22511679513073424)
# 14 truediv(10.0, mcp), mul(mkd, 0.23213547632124398)
# 15 128.0, truediv(mkd, 4.0)
# 16 mul(add(8.0, mul(4.0, 4.0)), m), mul(0.23107794139992588, mkd)
# 18 sub(sub(128.0, expit(128.0)), mul(mul(128.0, mcp), mcp)), mul(add(0.00390625, 0.2227244515510528), mkd)
# 20 pow(add(add(64.0, add(64.0, m)), m), expit(p)), truediv(mkd, 5.0)
# 21 add(m, mul(m, 10.0)), mul(mkd, 0.25)
# 22 mul(64.0, 0.8788816065809125), mul(mkd, 0.25)
# 23 128.0, truediv(mkd, add(add(0.41163256861675235, rc), add(rc, 4.0)))
# 24 truediv(n, 8.0), truediv(mkd, 5.0)
# 28 add(add(truediv(n, add(p, m)), add(m, mkd)), m), mul(0.2257766546491321, mkd)
# 29 128.0, truediv(mkd, add(truediv(rc, mul(mcp, mkd)), 4.0))
# 31 truediv(p, mcp), mul(mkd, 0.2487665327858929)
# 32 mul(n, mul(sub(m, mul(0.9531655474022283, mcp)), mkd)), mul(0.0025292618482459783, 0.6258857694987314)
# 36 64.0, mul(0.2329066438598818, mkd)
# 37 add(128.0, 16.0), truediv(mkd, add(pow(mul(add(rc, 4.0), rc), truediv(truediv(mkd, mkd), 16.0)), 4.0))
# 41 128.0, truediv(mkd, sub(add(5.0, truediv(rc, mcp)), expit(0.8840218626471321)))
# 43 add(64.0, mul(rc, 5.0)), mul(mkd, 0.21668540695459226)
# 45 128.0, truediv(mkd, 4.0)
# 49 128.0, truediv(mkd, add(0.3812177770720324, 4.0))
# 53 64.0, truediv(mkd, 5.0)
# 58 128.0, truediv(mkd, sub(sub(add(rc, 5.0), pow(0.00390625, rc)), 0.00390625))
# 219 truediv(128.0, mcp), mul(mul(0.00390625, add(0.49207598381585826, truediv(mkd, 0.25))), add(add(0.49207598381585826, truediv(mkd, 0.25)), mkd))
# 2074 128.0, mul(mkd, 0.21597797018727782)
# 2079 add(sub(64.0, 0.25), 64.0), mul(mkd, 0.2365158028102602)
# 3021 add(add(mul(n, mkd), m), m), mul(mkd, 0.23289272218465418)
# 3022 add(m, truediv(n, add(p, 0.7895461801279149))), mul(mkd, 0.2247272266877376)
# 3481 128.0, mul(0.9387947083614462, truediv(mkd, 4.0))
# 3485 128.0, mul(mkd, mul(sub(0.9463928454553887, 0.0078125), 0.25))
# 3492 128.0, truediv(mkd, add(4.0, 0.44467997422762007))
# 3493 truediv(add(p, mul(m, mkd)), mcp), mul(mkd, 0.2314600822793733)
# 3494 128.0, truediv(pow(pow(pow(mkd, expit(sub(truediv(rc, mkd), rc))), expit(truediv(rc, mkd))), expit(truediv(rc, mkd))), p)
# 3510 add(128.0, m), mul(0.24989412904561703, mkd)
# 3512 128.0, truediv(mkd, add(add(4.0, rc), truediv(rc, mkd)))
# 3543 truediv(expit(p), 0.0078125), mul(0.25, mkd)
# 3549 mul(m, add(m, add(m, 5.0))), truediv(mkd, add(pow(rc, mkd), 4.0))
# 3560 mul(9.0, m), mul(mkd, 0.25)
# 3561 truediv(add(16.0, 16.0), mcp), truediv(mkd, add(4.0, rc))
# 3567 mul(add(p, mkd), m), mul(0.22635164003923536, mkd)
# 3573 sub(128.0, sub(mul(mcp, mul(mcp, 8.0)), m)), mul(mkd, 0.2267271974720264)
# 3889 add(sub(mul(m, m), mkd), mul(mkd, n)), mul(0.23080454098466985, mkd)
# 3891 p, mul(0.2319623973297834, mkd)
# 3896 add(16.0, m), mul(pow(mkd, add(mkd, pow(rc, mcp))), mkd)
# 3899 pow(m, 4.0), truediv(mkd, add(4.0, mul(rc, m)))
# 3902 add(sub(sub(truediv(7.0, truediv(mcp, m)), mcp), 0.7071756954402434), mkd), mul(0.23424152147602884, mkd)
# 3904 add(128.0, add(9.0, 4.0)), truediv(mkd, 4.0)
# 3913 64.0, mul(0.25, mkd)
# 9986 128.0, truediv(mkd, add(mcp, add(4.0, pow(rc, pow(0.002714078032434619, m)))))
# 10093 add(sub(add(128.0, m), 8.0), m), mul(0.22318419495853759, mkd)
# 10101 64.0, truediv(mkd, 4.0)
# 14964 64.0, mul(0.22442683466712365, mkd)
# 14965 128.0, mul(0.9386265838028008, mul(0.25, mkd))
# 14966 mul(m, 10.0), mul(mkd, 0.25)
# 14967 sub(mul(mul(8.0, m), m), 16.0), mul(mkd, 0.23306557760768065)
# 14968 128.0, truediv(mkd, add(4.0, mcp))
# 14969 truediv(add(m, add(0.0625, mkd)), 0.12095979795954515), mul(0.25, mkd)
# 14970 128.0, mul(mkd, 0.24834678855063663)
# 34536 128.0, truediv(mkd, add(add(4.0, rc), mul(16.0, pow(rc, 0.00390625))))
# 34537 truediv(p, 0.3854002418481631), mul(0.23633594772411393, mkd)
# 34538 mul(truediv(mkd, mcp), n), mul(0.6836171104877201, 0.00390625)
# 34539 mul(m, 10.0), truediv(mkd, 4.0)
# 125920 mul(add(m, 0.03125), 9.0), mul(0.246566635743527, mkd)
# 125921 add(add(sub(16.0, m), 128.0), m), mul(0.24262662340174357, mkd)
# 125922 mul(128.0, add(mkd, 0.40750925745602506)), mul(mkd, 0.25)
# 125923 truediv(p, mcp), mul(mkd, 0.22707614955989575)
# 146195 mul(m, add(32.0, m)), mul(mkd, 0.2443190863587964)
# 146606 128.0, mul(mkd, sub(0.23612471488866638, 0.00390625))
# 146607 128.0, mul(0.19856351932145744, mkd)
# 3917 truediv(add(32.0, neg(rc)), mul(mcp, mcp)), mul(mkd, 0.25)
# 3918 32.0, mul(0.25, mkd)
# 3946 add(128.0, add(mcp, m)), mul(mkd, 0.24147290899077745)
# 3948 add(add(add(64.0, m), m), add(m, 64.0)), mul(mkd, 0.25)
# 3954 truediv(n, 7.0), truediv(mkd, 10.0)
# 7592 truediv(256.0, 2.0), mul(sub(0.2573223240003619, 0.00390625), mkd)
# 9914 add(128.0, 7.0), truediv(mkd, 4.0)
# 9946 truediv(32.0, mul(mcp, mcp)), truediv(mkd, 4.0)
# 9970 mul(add(mkd, m), add(16.0, 9.0)), mul(0.2212574685024764, mkd)
# 9971 sub(128.0, mcp), mul(0.2317540359478636, mkd)
# 9976 128.0, truediv(mkd, 6.0)
# 9977 mul(m, 9.0), mul(mkd, 0.25)
# 9978 sub(128.0, 3.0), mul(0.2748285720673146, mkd)
# 9979 128.0, mul(mkd, 0.1982068808293953)
# 9980 mul(32.0, m), mul(0.23364356247349038, mkd)
# 9981 add(5.0, sub(add(128.0, truediv(m, mcp)), rc)), mul(0.23528768357753427, mkd)
# 9983 add(truediv(128.0, mcp), rc), mul(expit(mcp), 0.00390625)
# 9985 mul(16.0, sub(sub(m, mcp), rc)), truediv(mkd, add(0.44104364384536376, 4.0))
# 9950 sub(128.0, 6.0), truediv(mkd, 4.0)
# 9952 mul(add(m, sub(add(sub(mkd, mcp), rc), mcp)), 32.0), mul(mkd, 0.20839902699244428)
# 9954 mul(10.0, m), mul(0.2264385002953042, mkd)
# 9955 add(128.0, 16.0), truediv(mkd, add(rc, 4.0))
# 9956 128.0, mul(0.233965090738664, mkd)

# %% [markdown]
# Expressions in the pareto-front with the least amount of operators:

# %%
for result in results:
    _, expr = min([(len(expr.split('(')), expr) for expr in result.top_five_expressions])
    print(result.task, expr)
# Out:
# 3 p, truediv(mkd, 3.0)
# 6 16.0, truediv(mkd, 3.0)
# 11 truediv(p, mcp), mul(0.22426512543927812, mkd)
# 12 add(truediv(n, p), 1.0), mul(mkd, 0.22511679513073424)
# 14 truediv(10.0, mcp), mul(mkd, 0.23213547632124398)
# 15 128.0, truediv(mkd, 4.0)
# 16 mul(add(8.0, m), m), mul(0.23107794139992588, mkd)
# 18 sub(sub(128.0, expit(128.0)), mul(mul(128.0, mcp), mcp)), mul(add(0.00390625, 0.2227244515510528), mkd)
# 20 add(add(add(64.0, add(64.0, m)), m), expit(64.0)), truediv(mkd, 5.0)
# 21 add(m, mul(m, 10.0)), mul(mkd, 0.25)
# 22 add(64.0, 0.8788816065809125), mul(mkd, 0.25)
# 23 128.0, truediv(mkd, add(0.41163256861675235, add(rc, 4.0)))
# 24 truediv(n, 8.0), truediv(mkd, 5.0)
# 28 add(truediv(n, add(p, m)), add(m, 0.125)), mul(0.2257766546491321, mkd)
# 29 128.0, truediv(mkd, add(truediv(rc, mul(mcp, mkd)), 4.0))
# 31 truediv(7.0, mcp), mul(mkd, 0.2487665327858929)
# 32 mul(n, mul(sub(m, 0.6258857694987314), mkd)), 0.0025292618482459783
# 36 64.0, mul(0.2329066438598818, mkd)
# 37 add(128.0, 16.0), truediv(mkd, add(pow(mul(rc, rc), truediv(mkd, 16.0)), 4.0))
# 41 128.0, truediv(mkd, sub(add(5.0, truediv(rc, mcp)), expit(0.8840218626471321)))
# 43 add(64.0, rc), mul(mkd, 0.21668540695459226)
# 45 128.0, truediv(mkd, 4.0)
# 49 128.0, truediv(mkd, add(0.3812177770720324, 4.0))
# 53 64.0, truediv(mkd, 5.0)
# 58 128.0, truediv(mkd, sub(5.0, sub(pow(0.00390625, rc), mcp)))
# 219 128.0, mul(0.00390625, add(add(0.49207598381585826, truediv(mkd, 0.25)), mkd))
# 2074 128.0, mul(mkd, 0.21597797018727782)
# 2079 add(64.0, 1.0), mul(mkd, 0.2365158028102602)
# 3021 add(add(mul(n, mkd), 0.0625), m), mul(mkd, 0.23289272218465418)
# 3022 add(m, truediv(n, p)), mul(mkd, 0.2247272266877376)
# 3481 128.0, truediv(mkd, 4.0)
# 3485 128.0, mul(mkd, mul(0.9463928454553887, 0.25))
# 3492 128.0, truediv(mkd, add(4.0, 0.3053817423193129))
# 3493 truediv(add(p, 0.17072838794309209), mcp), mul(mkd, 0.2314600822793733)
# 3494 128.0, truediv(pow(pow(pow(mkd, expit(truediv(rc, mkd))), expit(truediv(rc, mkd))), expit(truediv(rc, mkd))), p)
# 3510 128.0, mul(0.24989412904561703, mkd)
# 3512 128.0, truediv(mkd, add(add(4.0, rc), mcp))
# 3543 truediv(expit(mkd), 0.0078125), mul(0.25, mkd)
# 3549 mul(m, add(m, add(m, 5.0))), truediv(mkd, add(pow(rc, mcp), 4.0))
# 3560 mul(9.0, m), mul(mkd, 0.25)
# 3561 truediv(add(0.8397584146199527, 16.0), mcp), truediv(mkd, add(4.0, rc))
# 3567 mul(p, m), mul(0.22635164003923536, mkd)
# 3573 sub(128.0, mul(mcp, 8.0)), mul(mkd, 0.2267271974720264)
# 3889 add(add(mkd, mul(m, m)), mul(mkd, n)), mul(0.23080454098466985, mkd)
# 3891 p, mul(0.23036894779166328, mkd)
# 3896 add(16.0, m), mul(pow(mkd, pow(rc, mcp)), mkd)
# 3899 pow(m, 4.0), truediv(mkd, add(4.0, rc))
# 3902 add(sub(truediv(7.0, truediv(mcp, m)), mcp), mkd), mul(0.23424152147602884, mkd)
# 3904 add(128.0, add(9.0, 4.0)), truediv(mkd, 4.0)
# 3913 256.0, mul(0.25, mkd)
# 9986 128.0, truediv(mkd, add(mcp, add(4.0, pow(rc, 0.002714078032434619))))
# 10093 add(add(sub(128.0, 8.0), m), m), mul(0.22318419495853759, mkd)
# 10101 128.0, truediv(mkd, 7.0)
# 14964 64.0, mul(0.22442683466712365, mkd)
# 14965 128.0, mul(0.25, mkd)
# 14966 mul(m, 10.0), mul(mkd, 0.25)
# 14967 sub(mul(16.0, m), 16.0), mul(mkd, 0.23306557760768065)
# 14968 128.0, truediv(mkd, 4.0)
# 14969 truediv(m, 0.12095979795954515), mul(mul(0.25, 0.934343938704159), mkd)
# 14970 128.0, mul(mkd, 0.125)
# 34536 128.0, truediv(mkd, add(4.0, mul(16.0, rc)))
# 34537 p, mul(0.23361025550775172, mkd)
# 34538 mul(truediv(mkd, mcp), n), mul(0.09594168760765054, 0.015625)
# 34539 mul(8.0, 10.0), truediv(mkd, 5.0)
# 125920 mul(m, 9.0), mul(0.246566635743527, mkd)
# 125921 add(add(128.0, 4.0), m), mul(0.24262662340174357, mkd)
# 125922 128.0, mul(mkd, 0.25)
# 125923 truediv(p, mcp), mul(mkd, 0.22707614955989575)
# 146195 mul(m, 32.0), mul(mkd, 0.2443190863587964)
# 146606 128.0, mul(mkd, 0.23612471488866638)
# 146607 128.0, mul(0.19856351932145744, mkd)
# 3917 truediv(add(32.0, rc), mul(mcp, mcp)), mul(mkd, 0.25)
# 3918 32.0, mul(0.25, mkd)
# 3946 add(128.0, m), mul(mkd, 0.24147290899077745)
# 3948 add(add(add(64.0, m), m), 64.0), mul(mkd, 0.25)
# 3954 truediv(n, 7.0), truediv(mkd, 10.0)
# 7592 16.0, mul(0.29886269001906385, mkd)
# 9914 128.0, truediv(mkd, 4.0)
# 9946 truediv(32.0, mcp), truediv(mkd, 4.0)
# 9970 mul(m, add(0.015625, 9.0)), mul(0.2212574685024764, mkd)
# 9971 128.0, mul(0.2317540359478636, mkd)
# 9976 128.0, truediv(mkd, 6.0)
# 9977 mul(m, 10.0), mul(mkd, 0.25)
# 9978 sub(128.0, 0.2748285720673146), mul(0.2748285720673146, mkd)
# 9979 128.0, mul(mkd, 0.1982068808293953)
# 9980 mul(32.0, m), mul(0.23364356247349038, mkd)
# 9981 add(sub(128.0, rc), truediv(m, mcp)), mul(0.23528768357753427, mkd)
# 9983 truediv(128.0, mcp), mul(expit(mcp), 0.00390625)
# 9985 mul(16.0, sub(m, mcp)), truediv(mkd, add(0.44104364384536376, 4.0))
# 9950 128.0, truediv(mkd, 4.0)
# 9952 mul(add(m, sub(sub(rc, mcp), mcp)), 32.0), mul(mkd, 0.20828732335361477)
# 9954 mul(10.0, m), mul(0.2264385002953042, mkd)
# 9955 128.0, truediv(mkd, add(rc, 4.0))
# 9956 128.0, mul(0.233965090738664, mkd)
