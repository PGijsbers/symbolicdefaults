# %% [markdown]
# # Generated Hyperparameter Values
# This notebooks looks at the hyperparameter values generated by symbolic expressions.
# We want to identify if and when the generated hyperparameter values are out of bounds.
# Hyperparamater values are out of bound if they are not allowed by the algorithm, or outside of our experiment data.
#
# To collect the data for this experiment, we recorded for each evaluated individual the following data during one optimization trace:
#  - The **generation** of optimization in which the individual was considered
#  - The **individual** symbolic expression
#  - The **task** for which the expression was resolved to constant values
#  - The **hyperparameter values** that result from applying the **individual**'s expression on the given **task**'s meta-features.

# %% [markdown]
# ## RPart
# For RPart we have experiment data on the following hyperparameters ([docs](https://mlr3.mlr-org.com/reference/mlr_learners_classif.rpart.html?q=rpart)):
#
# | Hyperparameter | Default | Documented Range | Experimental Range |
# | :------------- | ------: | ---------------: | -----------------: |
# | cp             |  0.01   | \[0, 1\]         | \[2e-6, 0.997\]    |
# | max.depth      |  30     | \[1, 30\]        | \[1, 30\]          |
# | min.bucket     |  1      | \[1, ∞)          | \[1, 195\]         |
# | min.split      |  20     | \[1, ∞)          | \[1, 164\]         |
#
# Table 1. *The legal hyperparameter values for each hyperparameter per documentation compared to the values used in experiments.*

# %%
import sys
sys.path.append("./src/")
from src.problem import Problem
problem = Problem("mlr_rpart")
for hyperparameter in problem.hyperparameters:
    print(f"{hyperparameter}: [{problem.data[hyperparameter].min()},{problem.data[hyperparameter].max()}]")
# Out:
# cp: [1.97159e-06,0.996794]
# maxdepth: [1.0,30.0]
# minbucket: [1.0,195.0]
# minsplit: [1.0,164.0]

# %% [markdown]
# We optimized a symbolic expression holding out task 9986 (chosen arbitrarily), and collected the data described above.
# Our symbolic expressions once resolved can lead to ranges many orders of magnitude out of scale:

# %%
import pandas as pd
df = pd.read_csv("data/rpart_hp_big.csv", header=0, sep=';')

# %%
for hyperparameter in problem.hyperparameters:
    print(f"{hyperparameter}: [{df[hyperparameter].min()},{df[hyperparameter].max()}]")
# Out:
# cp: [-16916649214.586359,3.4142787736421956e+29]
# maxdepth: [-3.7131929274565926e+29,8.320664372691359e+29]
# minbucket: [-4.7063248002557094e+27,1.1227368346945231e+30]
# minsplit: [-1.1619031153871814e+30,1.1236536623544072e+30]

# %% [markdown]
# While an outlier is not necessarily a problem given the surrogate model should effectively truncate the value to the min (or max) of the experimental range, depending on how often this happens it may hurt optimization.

# %%
experiment_ranges = dict(
    cp=(0, 1),
    maxdepth=(1, 30),
    minbucket=(1, 195),
    minsplit=(1, 164),
)
def in_range(hyperparameter, value):
    return experiment_ranges[hyperparameter][0] <= value <=experiment_ranges[hyperparameter][1]

data = []
for hp in problem.hyperparameters:
    data.append({
        "hyperparameter": hp,
        "minimum": df[hp].min(),
        " 5%": df[hp].quantile(q=0.05),
        "25%": df[hp].quantile(q=0.25),
        "median": df[hp].median(),
        "25%": df[hp].quantile(q=0.75),
        "95%": df[hp].quantile(q=0.95),
        "maximum": df[hp].max(),
        "% in exp. range": sum(in_range(hp, v) for v in df[hp])/len(df),
    })
symb_ranges = pd.DataFrame(data)
symb_ranges
# Out:
#   hyperparameter       minimum         5%        25%     median         95%  \
# 0             cp -1.691665e+10   0.000001   0.002438   0.001548    0.533284
# 1       maxdepth -3.713193e+29  18.000000  26.000000  26.000000  144.936859
# 2      minbucket -4.706325e+27   0.360000  11.000000   9.000000   18.000000
# 3       minsplit -1.161903e+30   1.000000  27.000000  17.000000   94.794326
#
#         maximum  % in exp. range
# 0  3.414279e+29         0.946218
# 1  8.320664e+29         0.904493
# 2  1.122737e+30         0.900386
# 3  1.123654e+30         0.911982

# %% [markdown]
# Table 2. *An overview of the range of instantiated hyperparameter values.*

# %% [markdown]
# While >90% of evaluations are in hyperparameter range, we can still ask when it is not in range:
#  - does it depend on the task?
#  - does it depend on the generation?
#  - what is the effect of all-constants configurations on this number?

# %%
data = []
for i, row in df.iterrows():        
    data.append({
        f"{hp}_in_range": in_range(hp, row[hp])
        for hp in problem.hyperparameters
    })
is_in_range = pd.DataFrame(data)
df2 = pd.concat([df, is_in_range], axis=1)

# %%
import re
regex = re.compile(r"(\(|, )(m|mkd|p|n|mcp|rc|xvar)")

def is_constant(expr):
    return re.search(regex, expr) is None

df2['is_constant'] = df2.expression.apply(is_constant)

# %%
percentage_by_task = df2.groupby(by=['task']).agg(
    {c: lambda x: sum(x)/len(x) for c in is_in_range.columns}
)
percentage_by_task.describe()
# Out:
#        cp_in_range  maxdepth_in_range  minbucket_in_range  minsplit_in_range
# count   114.000000         114.000000          114.000000         114.000000
# mean      0.946218           0.904493            0.900386           0.911982
# std       0.002917           0.026824            0.085453           0.050645
# min       0.937277           0.867745            0.537639           0.655051
# 25%       0.944672           0.882601            0.911528           0.912659
# 50%       0.946481           0.884902            0.925493           0.927010
# 75%       0.948050           0.937224            0.933128           0.929909
# max       0.953237           0.946428            0.943555           0.936054

# %% [markdown]
# Table 3. *Summary of how many expressions are in range per hyperparameter by task. E.g. the task which has fewest expressions where `cp` is in range, still has it in range `93.7%` of the time.*

# %%
percentage_by_gen = df2.groupby(by=['gen']).agg(
    {c: lambda x: sum(x)/len(x) for c in list(is_in_range.columns) + ['is_constant']}
)
percentage_by_gen.describe()
# Out:
#        cp_in_range  maxdepth_in_range  minbucket_in_range  minsplit_in_range  \
# count   200.000000         200.000000          200.000000         200.000000
# mean      0.948815           0.908359            0.903617           0.915761
# std       0.099721           0.167671            0.054552           0.096442
# min       0.307110           0.210437            0.391431           0.343384
# 25%       0.953009           0.935470            0.893165           0.916157
# 50%       0.967321           0.955330            0.912969           0.938590
# 75%       0.979630           0.971889            0.928504           0.956346
# max       1.000000           1.000000            0.972552           0.997608
#
#        is_constant
# count   200.000000
# mean      0.083562
# std       0.058754
# min       0.000000
# 25%       0.041132
# 50%       0.073300
# 75%       0.117336
# max       0.250000

# %% [markdown]
# Table 4. *Aggregate for how often expressions are in range by generation. We see that in most generations most expressions are in range, though in the extreme case `<50%` are in range in one generation (this need not be the same generation for each hyperparameter).*

# %%
percentage_by_gen
# Out:
#      cp_in_range  maxdepth_in_range  minbucket_in_range  minsplit_in_range  \
# gen
# 0       0.540554           0.317244            0.391431           0.343384
# 1       0.496793           0.468497            0.664592           0.450104
# 2       0.307110           0.375993            0.649861           0.457341
# 3       0.326846           0.317708            0.719846           0.609101
# 4       0.312591           0.217288            0.862299           0.407255
# ..           ...                ...                 ...                ...
# 195     0.997852           0.961779            0.898317           0.930183
# 196     0.966851           0.945152            0.883934           0.912742
# 197     0.962943           0.969209            0.874239           0.920337
# 198     0.967901           0.986890            0.894833           0.961153
# 199     0.943489           1.000000            0.879049           0.941717
#
#      is_constant
# gen
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ..           ...
# 195     0.020408
# 196     0.000000
# 197     0.030612
# 198     0.043956
# 199     0.028846
#
# [200 rows x 5 columns]

# %% [markdown]
# Table 5. *Initial populations score poorly, but later generations seem generally in range.*
#
# This might be a sign that a good symbolic expression operates within the ranges of the hyperparameters. It could also be a sign that Symbolic Expressions are learnt which are effectively constants.

# %%
percentage_is_constant = df2.groupby(by=['is_constant']).agg(
    {c: lambda x: sum(x)/len(x) for c in is_in_range.columns}
)
percentage_is_constant
# Out:
#              cp_in_range  maxdepth_in_range  minbucket_in_range  \
# is_constant
# False           0.942558           0.900572            0.893777
# True            0.987063           0.948254            0.974127
#
#              minsplit_in_range
# is_constant
# False                 0.906703
# True                  0.970893

# %% [markdown]
# Table 6. *Even our constant expressions aren't always in range, though they are more likely to be than symbolic expressions.*

# %% [markdown]
# Are Symbolic Expressions effectively constant? This would be either because:
#  - The expression is always out-of-range, so it is truncated to constant values.
#  - The expression always evaluates to the same constant (e.g. `rc/rc`)

# %%
symbolic_expressions = df2[~df2.is_constant]

# %%
print(f"{symbolic_expressions.expression.nunique()} unique symbolic expressions were evaluated across {symbolic_expressions.task.nunique()} tasks.")
# Out:
# 12729 unique symbolic expressions were evaluated across 114 tasks.

# %%
percentage_by_expression = symbolic_expressions.groupby(by=['expression']).agg(
    {c: lambda x: sum(x)/len(x) for c in list(is_in_range.columns) + ['is_constant']}
)
percentage_by_expression.describe()
# Out:
#         cp_in_range  maxdepth_in_range  minbucket_in_range  minsplit_in_range
# count  12729.000000       12729.000000        12729.000000       12729.000000
# mean       0.929094           0.879929            0.875538           0.886815
# std        0.248183           0.293587            0.256377           0.279580
# min        0.000000           0.000000            0.000000           0.000000
# 25%        1.000000           1.000000            0.947368           0.964912
# 50%        1.000000           1.000000            0.956140           0.973684
# 75%        1.000000           1.000000            1.000000           1.000000
# max        1.000000           1.000000            1.000000           1.000000

# %% [markdown]
# Table 7. *Expressions are typically in range.*

# %%
percentage_by_expression[
    (percentage_by_expression.cp_in_range < 0.05) &
    (percentage_by_expression.maxdepth_in_range < 0.05) &
    (percentage_by_expression.minbucket_in_range < 0.05) &
    (percentage_by_expression.minsplit_in_range < 0.05)
]
# Out:
#                                                     cp_in_range  \
# expression
# make_tuple(neg(po), neg(rc), add(n, mkd), min(r...          0.0
# make_tuple(neg(po), neg(rc), n, min(rc, mcp))               0.0
# make_tuple(sub(neg(0.03935436677289785), max(rc...          0.0
# make_tuple(sub(neg(0.03935436677289785), max(rc...          0.0
# make_tuple(sub(rc, po), sub(0.00156244197189117...          0.0
#
#                                                     maxdepth_in_range  \
# expression
# make_tuple(neg(po), neg(rc), add(n, mkd), min(r...            0.00000
# make_tuple(neg(po), neg(rc), n, min(rc, mcp))                 0.00000
# make_tuple(sub(neg(0.03935436677289785), max(rc...            0.04386
# make_tuple(sub(neg(0.03935436677289785), max(rc...            0.00000
# make_tuple(sub(rc, po), sub(0.00156244197189117...            0.00000
#
#                                                     minbucket_in_range  \
# expression
# make_tuple(neg(po), neg(rc), add(n, mkd), min(r...            0.008772
# make_tuple(neg(po), neg(rc), n, min(rc, mcp))                 0.008772
# make_tuple(sub(neg(0.03935436677289785), max(rc...            0.000000
# make_tuple(sub(neg(0.03935436677289785), max(rc...            0.000000
# make_tuple(sub(rc, po), sub(0.00156244197189117...            0.000000
#
#                                                     minsplit_in_range  \
# expression
# make_tuple(neg(po), neg(rc), add(n, mkd), min(r...                0.0
# make_tuple(neg(po), neg(rc), n, min(rc, mcp))                     0.0
# make_tuple(sub(neg(0.03935436677289785), max(rc...                0.0
# make_tuple(sub(neg(0.03935436677289785), max(rc...                0.0
# make_tuple(sub(rc, po), sub(0.00156244197189117...                0.0
#
#                                                     is_constant
# expression
# make_tuple(neg(po), neg(rc), add(n, mkd), min(r...        False
# make_tuple(neg(po), neg(rc), n, min(rc, mcp))             False
# make_tuple(sub(neg(0.03935436677289785), max(rc...        False
# make_tuple(sub(neg(0.03935436677289785), max(rc...        False
# make_tuple(sub(rc, po), sub(0.00156244197189117...        False

# %% [markdown]
# Table 8. *Only the above 6 (of ~13k) symbolic expressions evaluate out of range for more than 95% tasks for all hyperparameters at the same time.*

# %%
# the following is some ugly code to help us compile the expressions outside of the normal script
from collections import namedtuple
from evolution import setup_toolbox

FakeArgs = namedtuple("FakeArgs", "constants_only optimize_constants max_start_size max_number_operators")

fake_args = FakeArgs(False, False, 3, 3)
toolbox, pset = setup_toolbox(problem, fake_args)

# integer numbers are not interpreted correctly unless we had a trailing period
# e.g. make_tuple(1, p, p, 2) does not work, but make_tuple(1., p, p, 2.) does
numbers = re.compile(r'(\(| )\d+(\)|,)')
def add_trailing_period(match):
    match_str = match.group(0)
    return match_str[:-1] + '.' + match_str[-1]

# %%
from deap import gp, creator

values_by_expression = {}
for str_expression in symbolic_expressions.expression.unique():
    values_by_task = {}
    fixed_expression = re.sub(numbers, add_trailing_period, str_expression)
    tree_expression = gp.PrimitiveTree.from_string(fixed_expression, pset)
    individual = creator.Individual(tree_expression)
    for task, metadata in problem.metadata.iterrows():
        symbolic_expression = gp.compile(individual, pset)
        hyperparameter_values = toolbox.evaluate(symbolic_expression, metadata)
        values_by_task[task] = hyperparameter_values
    values_by_expression[str_expression] = values_by_task
# Out:
# <string>:1: RuntimeWarning: overflow encountered in double_scalars
# <string>:1: RuntimeWarning: divide by zero encountered in double_scalars
# <string>:1: RuntimeWarning: invalid value encountered in double_scalars

# %%
expr_is_constant = {}
for expression, by_task in values_by_expression.items():
    a = pd.DataFrame.from_dict(by_task, columns=problem.hyperparameters, orient='index')
    expr_is_constant[expression] = all([v < 2 for v in (a.describe().loc['max'] - a.describe().loc['min'])])

# %%
print(f"{len([e for e, c in expr_is_constant.items() if c])} expressions evaluate to constants.")
# Out:
# 1711 expressions evaluate to constants.

# %%
[e for e, c in expr_is_constant.items() if c]
# Out:
# ['make_tuple(min(xvar, n), expit(n), add(mkd, 136.), min(mcp, po))',
#  'make_tuple(truediv(rc, rc), sub(mkd, mkd), min(m, mcp), sub(0.008483523159916725, mcp))',
#  'make_tuple(sub(mcp, 0.024184355866803904), if_gt(mkd, xvar, m, mkd), max(rc, mkd), pow(rc, mcp))',
#  'make_tuple(if_gt(truediv(rc, 1009.), max(112., po), mul(n, 0.01389005822292668), pow(p, n)), sub(pow(xvar, xvar), mul(p, rc)), neg(min(n, mkd)), mul(max(n, p), expit(444.)))',
#  'make_tuple(expit(p), pow(rc, mkd), min(rc, po), sub(mkd, 0.24995302167720845))',
#  'make_tuple(sub(sub(mcp, xvar), expit(0.17677585367839033)), truediv(if_gt(107., mkd, 0.1913097530238635, 58.), truediv(mkd, mkd)), sub(pow(12., 0.033353104720138874), max(mkd, 14.)), mul(pow(xvar, p), expit(mcp)))',
#  'make_tuple(neg(if_gt(mcp, rc, m, xvar)), pow(add(mkd, po), add(xvar, 2.)), pow(neg(po), max(p, n)), truediv(expit(n), mul(xvar, po)))',
#  'make_tuple(if_gt(n, xvar, mkd, 725.), neg(mcp), neg(4.), pow(xvar, m))',
#  'make_tuple(pow(0.020003428836256873, 0.5189762250643452), neg(1.), if_gt(m, mcp, 231., n), min(mkd, rc))',
#  'make_tuple(expit(if_gt(24., 3., 0.10582759573852574, po)), if_gt(mul(po, p), sub(mkd, mcp), sub(mcp, 0.190673803712085), truediv(mkd, 0.004655452368502992)), min(min(n, mcp), pow(n, m)), neg(truediv(mcp, po)))',
#  'make_tuple(truediv(rc, rc), sub(mkd, mkd), min(m, mcp), sub(expit(0.008483523159916725), mcp))',
#  'make_tuple(truediv(rc, rc), neg(sub(mkd, mkd)), min(m, mcp), sub(0.008483523159916725, mcp))',
#  'make_tuple(expit(mkd), max(mkd, 50.), min(mkd, m), mul(pow(xvar, p), expit(mcp)))',
#  'make_tuple(truediv(rc, rc), sub(mkd, mkd), min(m, mcp), sub(0.00839676162216141, mcp))',
#  'make_tuple(sub(mcp, 0.03238370610180673), if_gt(mkd, xvar, m, mkd), max(rc, mkd), pow(rc, mcp))',
#  'make_tuple(pow(0.020003428836256873, 0.5189762250643452), neg(1.), if_gt(2., mcp, 231., n), min(mkd, rc))',
#  'make_tuple(min(xvar, 4.), expit(n), add(mkd, 136.), min(mcp, po))',
#  'make_tuple(mcp, 4., sub(po, po), 3.)',
#  'make_tuple(truediv(rc, rc), sub(mkd, mkd), min(m, mcp), sub(0.008062374565717149, mcp))',
#  'make_tuple(sub(neg(0.03935436677289785), max(rc, n)), add(mul(m, p), neg(mcp)), min(add(mkd, 8.), neg(po)), sub(sub(rc, m), pow(po, 505.)))',
#  'make_tuple(neg(if_gt(xvar, m, 25., mkd)), if_gt(pow(xvar, rc), sub(p, n), max(25., m), min(po, m)), add(add(mkd, xvar), add(mcp, 11.)), truediv(max(pow(n, n), n), mcp))',
#  'make_tuple(0.002514566436442558, p, add(add(mkd, xvar), add(mcp, 10.)), sub(sub(rc, m), pow(po, n)))',
#  'make_tuple(0.002110436541599389, pow(p, n), 11., m)',
#  'make_tuple(mul(0.002652122571281584, rc), 28., 13., pow(mcp, mcp))',
#  'make_tuple(mul(0.002652122571281584, mcp), 28., 13., 271.)',
#  'make_tuple(mul(0.002652122571281584, mcp), 77., 9., 5.)',
#  'make_tuple(0.002218412445769265, 165., 12., max(6., mkd))',
#  'make_tuple(mul(0.002652122571281584, mcp), 77., 12., 5.)',
#  'make_tuple(mul(0.002652122571281584, mcp), 77., 10., 5.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 28., 12., 6.)',
#  'make_tuple(pow(0.0030894799993390425, 0.0016400428722957918), 165., 11., 6.)',
#  'make_tuple(mul(0.002652122571281584, mcp), 77., 9., 7.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 165., 12., 6.)',
#  'make_tuple(mul(mkd, mcp), 77., 9., 5.)',
#  'make_tuple(mul(0.002652122571281584, mcp), 85., 9., 5.)',
#  'make_tuple(rc, 165., 11., 6.)',
#  'make_tuple(mul(rc, mcp), 77., 9., 5.)',
#  'make_tuple(mcp, 67., 9., 6.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 28., 12., 190.)',
#  'make_tuple(mul(0.0027680701689408913, mul(11., mcp)), 28., 12., 6.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 30., 12., 6.)',
#  'make_tuple(mul(0.002652122571281584, mcp), 26., 9., 6.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 26., 9., 6.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 26., 9., 1.)',
#  'make_tuple(pow(0.0027680701689408913, mcp), 28., 12., 6.)',
#  'make_tuple(mul(0.002652122571281584, mcp), 26., 9., 10.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 26., 9., 0.)',
#  'make_tuple(mul(0.015413572237677316, mcp), 26., 9., 6.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 26., 10., 6.)',
#  'make_tuple(mul(0.0027680701689408913, mkd), 26., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 28., 9., 1.)',
#  'make_tuple(mul(0.002652122571281584, mcp), 32., 9., 6.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), expit(26.), 9., 1.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 28., 9., 6.)',
#  'make_tuple(if_gt(mul(0.0027680701689408913, mcp), n, mcp, xvar), 26., 9., 1.)',
#  'make_tuple(mcp, 26., 9., 1.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 1.)',
#  'make_tuple(mul(0.002652122571281584, mcp), 28., 9., 6.)',
#  'make_tuple(mul(0.002652122571281584, rc), 26., 9., 6.)',
#  'make_tuple(mul(0.002553715938366321, mcp), 26., 9., 6.)',
#  'make_tuple(mul(mkd, mcp), 26., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 6.)',
#  'make_tuple(add(0.002951411239350204, mcp), 28., 9., 1.)',
#  'make_tuple(mul(0.002652122571281584, mcp), 701., 9., 10.)',
#  'make_tuple(mcp, 26., 9., 6.)',
#  'make_tuple(truediv(0.0027680701689408913, mcp), 26., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 29., 9., 1.)',
#  'make_tuple(mul(rc, mcp), 26., 9., 1.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 27., 9., 6.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 28., 10., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 28., 9., 79.)',
#  'make_tuple(mul(0.002553715938366321, mcp), 26., 8., 6.)',
#  'make_tuple(mul(0.0022207273237671325, mcp), 26., 9., 0.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 28., 9., 6.)',
#  'make_tuple(mul(0.01663795718874028, mcp), 26., 9., 10.)',
#  'make_tuple(neg(0.0018020843177069088), 28., 10., 5.)',
#  'make_tuple(mcp, 26., 9., 10.)',
#  'make_tuple(mcp, 26., 9., 0.)',
#  'make_tuple(0.0018020843177069088, 28., 10., max(6., xvar))',
#  'make_tuple(mul(0.002652122571281584, mcp), 28., 9., 10.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 8., 1.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 19., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, 0.008986576968189575), 26., 9., 1.)',
#  'make_tuple(mul(0.0027680701689408913, mcp), 28., 9., 1.)',
#  'make_tuple(mul(0.002553715938366321, mcp), 26., 9., min(0.5055215327083896, 6.))',
#  'make_tuple(mul(mcp, mcp), 26., 9., 0.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 7.)',
#  'make_tuple(mul(0.0022207273237671325, mcp), 26., 9., 1.)',
#  'make_tuple(mul(0.0026196776077377017, mcp), 26., 9., 1.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 28., 9., 601.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 28., 10., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 2., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 0.)',
#  'make_tuple(0.0018020843177069088, 28., min(9., rc), 1.)',
#  'make_tuple(0.0018020843177069088, 28., 9., truediv(mcp, m))',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 10., 1.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., truediv(mcp, m))',
#  'make_tuple(mul(0.003112303534069458, mcp), 26., 9., 6.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 28., 9., 1.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 29., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), max(28., 0.13644671178142853), 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 28., 9., truediv(mcp, m))',
#  'make_tuple(xvar, 26., 11., 6.)',
#  'make_tuple(truediv(0.0016400428722957918, n), 26., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 150.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 7., 7.)',
#  'make_tuple(mul(0.061354940681398296, 0.0018020843177069088), 26., 9., 6.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 27., pow(9., 0.008327722376031412), 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 5.)',
#  'make_tuple(0.0016400428722957918, min(26., rc), 9., 6.)',
#  'make_tuple(mul(0.003449181979797212, mcp), 26., 9., 1.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 26., mul(0.6379239820197022, 9.), 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 11., 1.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 30., 9., 1.)',
#  'make_tuple(mcp, 28., 9., 1.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 679., 9., 6.)',
#  'make_tuple(mcp, 26., 9., 7.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 28., 9., 6.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 26., 10., 6.)',
#  'make_tuple(0.0018020843177069088, sub(26., xvar), 9., 5.)',
#  'make_tuple(max(0.003112303534069458, mcp), 28., 9., 1.)',
#  'make_tuple(max(0.003112303534069458, mcp), 26., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 29., 9., 0.)',
#  'make_tuple(mul(0.002951411239350204, sub(mcp, rc)), 26., 9., 0.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 34., 1.)',
#  'make_tuple(add(2., mul(0.002951411239350204, mcp)), 26., 9., 1.)',
#  'make_tuple(0.0016400428722957918, 26., 9., min(xvar, 6.))',
#  'make_tuple(mul(0.003112303534069458, mcp), 28., pow(9., n), 6.)',
#  'make_tuple(0.0018020843177069088, 26., min(0.088539792958425, 9.), 5.)',
#  'make_tuple(0.0016400428722957918, 26., 9., truediv(rc, 6.))',
#  'make_tuple(mul(0.001616996313385265, mcp), 26., 9., 7.)',
#  'make_tuple(0.0016400428722957918, pow(26., 6.), 9., 6.)',
#  'make_tuple(mul(truediv(0.002951411239350204, 0.01994263698873669), mcp), 26., 9., 1.)',
#  'make_tuple(neg(mul(0.003112303534069458, mcp)), 26., 9., 6.)',
#  'make_tuple(xvar, 26., 9., 5.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 2.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., mul(1., 9.), 7.)',
#  'make_tuple(0.0016400428722957918, pow(26., n), 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, 0.025343494631779616), 26., 9., 7.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 156., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.003285585993732871, mcp), 26., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 27., 9., 1.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 21., 9., 7.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 27., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, 0.013881929682603012), 26., 9., 1.)',
#  'make_tuple(mul(0.003112303534069458, rc), 26., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 7., 26.)',
#  'make_tuple(0.0016400428722957918, min(n, 26.), 9., 5.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 26., sub(9., xvar), 6.)',
#  'make_tuple(mul(xvar, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, rc), 26., 9., 26.)',
#  'make_tuple(mul(0.003112303534069458, min(xvar, mcp)), 26., 9., 6.)',
#  'make_tuple(0.0018020843177069088, pow(mcp, 26.), 9., 7.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., min(9., xvar), 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), if_gt(n, 26., xvar, mkd), 9., 5.)',
#  'make_tuple(mul(truediv(0.002951411239350204, mcp), mcp), 26., 9., 5.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(9., expit(xvar)), 7.)',
#  'make_tuple(mul(0.002951411239350204, mul(mcp, mkd)), 26., 9., 7.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 8., 5.)',
#  'make_tuple(mul(0.002951411239350204, 0.020544200364672336), 26., 9., 7.)',
#  'make_tuple(rc, 26., 9., 7.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 26., 9., 5.)',
#  'make_tuple(expit(mul(0.002951411239350204, mcp)), 26., 9., 2.)',
#  'make_tuple(0.0016400428722957918, 26., truediv(mkd, 9.), 7.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., add(7., mkd))',
#  'make_tuple(mul(0.0028131675707108476, mcp), 26., 9., 2.)',
#  'make_tuple(mcp, 26., 9., 26.)',
#  'make_tuple(max(mul(0.002951411239350204, mcp), 0.3391904168414696), 26., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 8., 2.)',
#  'make_tuple(0.0018020843177069088, 26., if_gt(9., xvar, 0.0018800429882886102, m), 5.)',
#  'make_tuple(mul(0.002951411239350204, 0.04955167356427298), 26., 9., 5.)',
#  'make_tuple(mul(max(0.002951411239350204, 0.024760184583091253), mcp), 26., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 25., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(9., mul(n, xvar)), add(7., mkd))',
#  'make_tuple(0.0018020843177069088, if_gt(26., mkd, xvar, mkd), 9., 26.)',
#  'make_tuple(mul(0.002938724881235729, mcp), 26., 9., 5.)',
#  'make_tuple(mul(max(0.002951411239350204, rc), mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 10., 9., 7.)',
#  'make_tuple(mul(0.003112303534069458, pow(mcp, 0.22716260023531235)), 26., 9., 6.)',
#  'make_tuple(mul(truediv(0.002951411239350204, 34.), mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.003112303534069458, mkd), 26., 9., 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 10., 5.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 27., 9., 7.)',
#  'make_tuple(expit(mul(0.002951411239350204, mcp)), 26., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., max(9., xvar), 7.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 25., 9., 2.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., max(sub(9., mkd), xvar), 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(rc, xvar), 5.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 26., 4., 5.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 26., min(9., 1.), 6.)',
#  'make_tuple(mul(0.002938724881235729, mcp), 22., 9., 5.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(9., 0.04173437011783641), 20.)',
#  'make_tuple(mul(0.002938724881235729, mcp), 26., min(mcp, 9.), 5.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 27., 9., 26.)',
#  'make_tuple(mcp, 26., 9., 5.)',
#  'make_tuple(mul(0.002938724881235729, mcp), 207., 9., 5.)',
#  'make_tuple(mul(xvar, mcp), 26., 9., 6.)',
#  'make_tuple(mul(1., mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.002670899969723822, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, 0.0015775079571414103), 26., 9., 26.)',
#  'make_tuple(0.0018020843177069088, 26., 9., min(0.20633865705374596, 26.))',
#  'make_tuple(mul(0.002951411239350204, mcp), 27., 9., 5.)',
#  'make_tuple(mul(0.003112303534069458, mcp), 26., 9., 7.)',
#  'make_tuple(min(m, 0.0016400428722957918), 26., 9., 26.)',
#  'make_tuple(0.0016400428722957918, 26., 9., mul(0.025504135581346864, 26.))',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(sub(pow(9., mkd), mkd), xvar), 6.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 5., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 20.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 27.)',
#  'make_tuple(rc, 26., 9., 26.)',
#  'make_tuple(0.0016400428722957918, max(0.27019573647831807, 26.), 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 27., sub(mkd, 9.), 26.)',
#  'make_tuple(mul(0.002938724881235729, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.0033109138573066367, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.003204049692044495, xvar), 26., 9., 26.)',
#  'make_tuple(mul(0.7952587313811448, mcp), 26., 9., 26.)',
#  'make_tuple(rc, 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., if_gt(m, mkd, 9., m), 27.)',
#  'make_tuple(mul(0.002938724881235729, mcp), 26., pow(9., 2.), 26.)',
#  'make_tuple(0.0016281156317994806, 26., 9., max(28., xvar))',
#  'make_tuple(mcp, 26., 9., 27.)',
#  'make_tuple(mul(0.003136954785018696, mcp), 26., 9., 20.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(9., expit(xvar)), 28.)',
#  'make_tuple(0.0016281156317994806, neg(26.), 9., 26.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 9., 27.)',
#  'make_tuple(0.0016281156317994806, 26., 9., sub(26., xvar))',
#  'make_tuple(mul(0.003204049692044495, mcp), min(26., mcp), 9., 26.)',
#  'make_tuple(mul(0.002938724881235729, 84.), 26., 9., 26.)',
#  'make_tuple(mul(0.002938724881235729, mcp), expit(26.), 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(9., 0.056691106379834516), 28.)',
#  'make_tuple(mul(0.002938724881235729, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 21.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 9., 27.)',
#  'make_tuple(0.0016281156317994806, 26., 9., mul(28., 0.005890851507040381))',
#  'make_tuple(min(mcp, mul(0.002951411239350204, mcp)), 26., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 25.)',
#  'make_tuple(mul(0.002893240229869964, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 27., 9., 28.)',
#  'make_tuple(add(0.0030976826328270716, mcp), 26., 9., 27.)',
#  'make_tuple(mul(mcp, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 2., 26.)',
#  'make_tuple(0.0016281156317994806, 26., 9., max(27., mkd))',
#  'make_tuple(0.0017450019883492275, 26., sub(xvar, 9.), 26.)',
#  'make_tuple(0.0016400428722957918, 26., truediv(mkd, 10.), 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 7., 9., 26.)',
#  'make_tuple(mul(0.003204049692044495, mcp), neg(26.), 9., 26.)',
#  'make_tuple(mul(0.003204049692044495, mcp), if_gt(26., po, rc, xvar), 9., 27.)',
#  'make_tuple(sub(0.0030976826328270716, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(min(9., mkd), xvar), 27.)',
#  'make_tuple(mul(0.002938724881235729, mcp), 26., pow(9., truediv(xvar, 550.)), 26.)',
#  'make_tuple(pow(0.002938724881235729, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.003204049692044495, 0.19981644530638248), 26., 9., 26.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 14., 9., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 10., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), sub(26., rc), 9., 27.)',
#  'make_tuple(mcp, 26., 9., 28.)',
#  'make_tuple(pow(0.002951411239350204, mcp), 26., 9., 26.)',
#  'make_tuple(xvar, 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 2., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mkd), 26., 9., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., expit(27.))',
#  'make_tuple(mkd, 26., 9., 27.)',
#  'make_tuple(neg(0.0016281156317994806), 26., 9., 28.)',
#  'make_tuple(0.001643906354613297, 26., min(9., rc), 27.)',
#  'make_tuple(mul(sub(mkd, 0.0030976826328270716), mcp), 26., 9., 27.)',
#  'make_tuple(0.0016281156317994806, 25., 9., mul(0.047462465726548594, 28.))',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 9., 22.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 22.)',
#  'make_tuple(mul(0.003204049692044495, neg(mcp)), 26., 9., 26.)',
#  'make_tuple(sub(0.002951411239350204, mcp), 26., 9., 27.)',
#  'make_tuple(mul(expit(0.002951411239350204), mcp), 26., 9., 27.)',
#  'make_tuple(0.0016281156317994806, max(26., rc), 9., 28.)',
#  'make_tuple(expit(mul(0.003204049692044495, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 9., 22.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 312., 9., 27.)',
#  'make_tuple(mul(0.002938724881235729, mcp), 403., 9., 28.)',
#  'make_tuple(min(n, mul(0.002951411239350204, mcp)), 26., 9., 22.)',
#  'make_tuple(mul(0.003204049692044495, max(0.4603441393154089, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, 1.), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., 567.)',
#  'make_tuple(min(mcp, mul(0.002951411239350204, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(pow(0.002951411239350204, po), mcp), 26., 9., 27.)',
#  'make_tuple(min(mkd, 0.0016281156317994806), 26., 9., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 9., 20.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 9., 28.)',
#  'make_tuple(if_gt(rc, 0.0016281156317994806, 0.2022735289119308, xvar), 26., 9., 28.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 80., 27.)',
#  'make_tuple(mul(0.003288607508083625, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0030976826328270716, rc), 26., 9., 27.)',
#  'make_tuple(min(mcp, mul(0.002951411239350204, mcp)), 26., max(9., xvar), 26.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 9., 29.)',
#  'make_tuple(mul(7., 0.0016400428722957918), 26., 9., 27.)',
#  'make_tuple(mul(min(0.002951411239350204, 0.02367154838892021), mcp), 26., 9., 22.)',
#  'make_tuple(0.001643906354613297, 26., 9., if_gt(9., 27., po, 2.))',
#  'make_tuple(mul(0.003204049692044495, mcp), 23., 9., 27.)',
#  'make_tuple(mcp, 26., 9., 22.)',
#  'make_tuple(mul(0.003076410107886891, mcp), 26., 9., 22.)',
#  'make_tuple(max(0.003204049692044495, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(9., n), 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., mul(9., 0.9617068173761697), 27.)',
#  'make_tuple(min(n, mul(0.002951411239350204, mcp)), 26., 9., sub(22., mcp))',
#  'make_tuple(neg(mul(0.003204049692044495, mcp)), 26., 9., 26.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 569., 9., 26.)',
#  'make_tuple(mul(0.0030976826328270716, xvar), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 10., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), pow(n, 26.), 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 7., 27.)',
#  'make_tuple(min(0.018272758359821943, mul(0.002951411239350204, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 22., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., mul(9., 0.3816192583407242), 27.)',
#  'make_tuple(mul(0.002951411239350204, m), 26., 9., 27.)',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., pow(xvar, mul(9., xvar)), 26.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 7., 26.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 22., 9., 27.)',
#  'make_tuple(mcp, 26., 10., 27.)',
#  'make_tuple(neg(mul(0.003204049692044495, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., min(9., xvar), sub(22., mcp))',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 299., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), max(mkd, 26.), 9., 27.)',
#  'make_tuple(min(mcp, mul(min(po, 0.002951411239350204), mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 22., 9., 27.)',
#  'make_tuple(0.0017450019883492275, 26., 9., add(27., mcp))',
#  'make_tuple(0.0017450019883492275, 26., 9., max(0.016464628111364336, 27.))',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 11., 27.)',
#  'make_tuple(sub(0.0015045395466195847, rc), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 7., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., sub(9., xvar), sub(22., mcp))',
#  'make_tuple(0.0015386973325914777, min(0.009523538199607037, 26.), 9., 27.)',
#  'make_tuple(min(0.018272758359821943, mul(0.002951411239350204, mcp)), 26., mul(pow(9., n), xvar), 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 8., 27.)',
#  'make_tuple(0.0015045395466195847, pow(mcp, 26.), 9., 28.)',
#  'make_tuple(mul(neg(0.002951411239350204), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., add(27., rc))',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., mul(2., xvar), 27.)',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., 9., 27.)',
#  'make_tuple(mul(min(0.0030976826328270716, p), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., mul(9., 0.001841331662231344), 27.)',
#  'make_tuple(0.0015386973325914777, 26., pow(221., 9.), 27.)',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., 10., 27.)',
#  'make_tuple(mul(mkd, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., pow(9., 0.001031695229795214), sub(22., mcp))',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., add(9., xvar), 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 9., 372.)',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0030976826328270716, m), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., 9., sub(22., mcp))',
#  'make_tuple(0.0015386973325914777, 26., pow(10., 0.0028974376971763285), 27.)',
#  'make_tuple(min(mcp, mul(min(po, 0.002951411239350204), mcp)), 26., mul(9., 0.01465682344003272), 27.)',
#  'make_tuple(0.0015862098815102447, 26., 9., pow(27., n))',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 32., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), if_gt(26., po, xvar, 2.), 9., 26.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), min(26., 0.009097645985094003), 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 10., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 27.)',
#  'make_tuple(min(mcp, mul(0.002951411239350204, mcp)), 26., 9., 28.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 10., 27.)',
#  'make_tuple(0.0015045395466195847, pow(n, 26.), 9., 28.)',
#  'make_tuple(sub(mcp, 0.0015386973325914777), 26., 10., 27.)',
#  'make_tuple(max(0.0015386973325914777, rc), 26., 9., 27.)',
#  'make_tuple(max(0.0050851144912987195, 0.0015386973325914777), 26., 9., 28.)',
#  'make_tuple(mul(0.0029473288191637155, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 26., min(9., xvar), 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., neg(27.))',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 9., 3.)',
#  'make_tuple(min(0.0015386973325914777, mkd), 26., 9., 28.)',
#  'make_tuple(mul(0.0030187917662654945, mcp), 26., mul(10., 0.0012803280052854124), 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 9., sub(386., 27.))',
#  'make_tuple(mul(0.0030187917662654945, mcp), 26., 10., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mkd), 26., 9., 27.)',
#  'make_tuple(expit(mul(0.0031978614174648545, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.003249406475757828, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 26., 10., if_gt(27., n, po, mcp))',
#  'make_tuple(mul(0.003204049692044495, 0.0036954911666602763), 26., 9., 27.)',
#  'make_tuple(mul(max(0.002951411239350204, rc), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mkd), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, pow(mcp, 0.0012498869757671496)), 26., 9., 27.)',
#  'make_tuple(min(0.018272758359821943, mul(0.002951411239350204, mcp)), 26., sub(9., xvar), 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 73., 9., 27.)',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., max(9., xvar), 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 24., 9., 27.)',
#  'make_tuple(mul(rc, mcp), 26., 9., 27.)',
#  'make_tuple(mkd, 26., 9., 28.)',
#  'make_tuple(mul(0.0031978614174648545, m), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., expit(mul(9., xvar)), add(27., rc))',
#  'make_tuple(xvar, 26., 11., 27.)',
#  'make_tuple(0.0015386973325914777, 26., 10., if_gt(27., rc, xvar, xvar))',
#  'make_tuple(mul(0.0030187917662654945, mcp), 26., 11., 27.)',
#  'make_tuple(0.0015386973325914777, 26., 11., truediv(mkd, 27.))',
#  'make_tuple(mul(0.0030187917662654945, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.003279580692046313, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 26., mul(9., 0.0795053979184504), add(27., rc))',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., min(mul(9., xvar), rc), 27.)',
#  'make_tuple(pow(0.003204049692044495, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 10., 28.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., max(695., 27.))',
#  'make_tuple(min(0.01772303232033614, mul(0.0029699264181608704, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002951411239350204, mcp), 495., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., if_gt(m, mcp, 18., mul(9., xvar)), 27.)',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., 10., 28.)',
#  'make_tuple(0.0015386973325914777, 26., neg(10.), 28.)',
#  'make_tuple(truediv(mul(0.003204049692044495, mcp), po), 26., 9., 27.)',
#  'make_tuple(mul(xvar, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 24.)',
#  'make_tuple(mul(0.0030187917662654945, mcp), 21., 11., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 8., 27.)',
#  'make_tuple(0.0015386973325914777, 26., neg(11.), 27.)',
#  'make_tuple(mul(0.003204049692044495, truediv(xvar, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 11., 27.)',
#  'make_tuple(min(0.0030187917662654945, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 9., 30.)',
#  'make_tuple(mul(0.0030187917662654945, mcp), 26., mul(9., 17.), 27.)',
#  'make_tuple(0.0015386973325914777, 26., 11., add(xvar, 27.))',
#  'make_tuple(mul(0.0022487599163805165, mcp), 26., 9., 27.)',
#  'make_tuple(mul(mul(0.003204049692044495, 0.24454309299654817), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), if_gt(26., 47., po, mcp), 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 8., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 9., expit(27.))',
#  'make_tuple(mul(0.003204049692044495, 0.00824525735571124), 26., 9., 30.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 10.)',
#  'make_tuple(0.0015386973325914777, max(21., 0.2557612810571527), 11., 28.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., sub(9., xvar), 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., 30.)',
#  'make_tuple(mul(0.003204049692044495, 0.020687534207165705), 26., 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 11., 30.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., if_gt(9., p, rc, 0.23532150958435893), 30.)',
#  'make_tuple(mul(0.0030187917662654945, rc), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 21., 11., 28.)',
#  'make_tuple(pow(0.0015386973325914777, mkd), 26., 11., 27.)',
#  'make_tuple(sub(0.003204049692044495, mcp), 26., 9., 30.)',
#  'make_tuple(mul(0.0030187917662654945, mcp), 26., mul(9., 0.26706519852899724), 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 9., if_gt(mcp, 27., m, rc))',
#  'make_tuple(min(0.01772303232033614, mul(0.0029699264181608704, mcp)), 25., 11., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 27., 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 9., 33.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 25., 9., 27.)',
#  'make_tuple(mul(0.0030158693418573888, mcp), 26., 11., 27.)',
#  'make_tuple(0.0015386973325914777, max(26., xvar), 9., 28.)',
#  'make_tuple(mul(expit(0.0030187917662654945), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, min(rc, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.0030043145992078996, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 21., neg(11.), 28.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 5., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 11., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 11., 28.)',
#  'make_tuple(mul(0.003204049692044495, 293.), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, sub(mcp, 334.)), 26., 9., 27.)',
#  'make_tuple(max(7., 0.0015386973325914777), 26., 11., 28.)',
#  'make_tuple(mul(0.0028044744569802687, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, 0.07669597139844093), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., expit(mul(10., xvar)), 27.)',
#  'make_tuple(mcp, 26., 9., 30.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 25., 9., 30.)',
#  'make_tuple(min(0.01772303232033614, mul(0.0029699264181608704, mcp)), 26., max(10., xvar), 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 236., 27.)',
#  'make_tuple(0.0015386973325914777, 25., mul(46., 11.), 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., if_gt(77., 91., mcp, 9.), 30.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., pow(rc, 27.))',
#  'make_tuple(mul(0.002954589286502831, mcp), 25., 11., 28.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., sub(9., xvar), 28.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., 25.)',
#  'make_tuple(neg(0.0015386973325914777), 25., 11., 28.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 21., 9., 28.)',
#  'make_tuple(mkd, 26., 11., 28.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 30.)',
#  'make_tuple(0.0015386973325914777, sub(mkd, 26.), 11., 28.)',
#  'make_tuple(truediv(mul(0.0029699264181608704, mcp), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 24., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 2., 27.)',
#  'make_tuple(mul(0.002954589286502831, 0.06645832996295882), 26., 9., 27.)',
#  'make_tuple(mcp, 21., 11., 29.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., neg(9.), 27.)',
#  'make_tuple(mcp, 26., 11., 28.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., add(9., xvar), 27.)',
#  'make_tuple(mul(0.0034187766578763364, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 25., 11., 28.)',
#  'make_tuple(mul(0.002954589286502831, add(0.03773779777425317, mcp)), 26., 9., 27.)',
#  'make_tuple(xvar, 25., 11., 28.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 27., 9., 27.)',
#  'make_tuple(mul(0.0030976826328270716, mcp), 23., 9., 27.)',
#  'make_tuple(0.0015386973325914777, truediv(xvar, 21.), 11., 28.)',
#  'make_tuple(0.0015386973325914777, 26., min(11., 0.002674271454176753), 29.)',
#  'make_tuple(mul(0.0030108708694321167, mcp), 26., 11., 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., 11., 28.)',
#  'make_tuple(mul(0.0030108708694321167, mcp), 21., 11., 28.)',
#  'make_tuple(0.0015386973325914777, neg(22.), 11., 28.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 22., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 22., 9., 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 25., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 11., 29.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.0035058697085124965, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., truediv(mkd, 29.))',
#  'make_tuple(mul(0.0032995417873681486, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., 11., 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 3., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., 5.)',
#  'make_tuple(0.0015386973325914777, min(mcp, 26.), 11., 29.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., sub(9., xvar), 27.)',
#  'make_tuple(mul(0.002954589286502831, add(mcp, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., 29.)',
#  'make_tuple(mul(0.0036778991522109124, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., 10.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 28., 9., 27.)',
#  'make_tuple(mul(0.004195700174830531, mcp), 26., 9., 27.)',
#  'make_tuple(min(0.01772303232033614, mul(0.0029699264181608704, mcp)), 26., 11., 28.)',
#  'make_tuple(neg(0.0015386973325914777), 26., 11., 28.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., 8., 27.)',
#  'make_tuple(truediv(0.002954589286502831, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0030187917662654945, mcp), 26., sub(9., xvar), 27.)',
#  'make_tuple(0.0015386973325914777, add(26., rc), 11., 28.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., mul(9., 0.009292541608837203), 27.)',
#  'make_tuple(truediv(0.0029699264181608704, mcp), 26., 9., 27.)',
#  'make_tuple(add(606., mul(0.002954589286502831, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 22., 9., 30.)',
#  'make_tuple(pow(0.0029699264181608704, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 26., 11., if_gt(mkd, po, 28., mcp))',
#  'make_tuple(min(0.003204049692044495, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002907141738039321, mcp), 26., 9., 27.)',
#  'make_tuple(min(0.01772303232033614, mul(0.0029699264181608704, mcp)), 26., pow(9., pow(xvar, 0.0034277930613763005)), 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., 9., 23.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 27., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(expit(9.), xvar), 27.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., 11., 28.)',
#  'make_tuple(mul(0.002954589286502831, mcp), truediv(mkd, 26.), 9., 27.)',
#  'make_tuple(pow(xvar, 0.0015386973325914777), 22., 11., 29.)',
#  'make_tuple(mul(0.003204049692044495, 0.004882552668079646), 26., 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 70., 9., 27.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., mul(9., 0.39302559374206636), 27.)',
#  'make_tuple(0.0015386973325914777, add(mkd, 22.), 11., 30.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 6., 9., 27.)',
#  'make_tuple(min(0.01772303232033614, mul(0.0029699264181608704, mcp)), 26., min(10., pow(xvar, rc)), 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 22., 9., 30.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 10., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 354.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 11., 30.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., neg(9.), 27.)',
#  'make_tuple(pow(0.026399216075378918, mul(0.003204049692044495, mcp)), 26., 9., 27.)',
#  'make_tuple(min(0.018111297654914427, mul(0.0029699264181608704, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 13., 27.)',
#  'make_tuple(neg(0.0015386973325914777), 22., 11., 28.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., 9., 27.)',
#  'make_tuple(min(0.01772303232033614, mul(0.0029699264181608704, mcp)), 26., mul(9., pow(xvar, mkd)), 27.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 26., 11., add(xvar, 28.))',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(truediv(9., n), xvar), 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., truediv(9., n), 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 22., 11., 29.)',
#  'make_tuple(0.0015386973325914777, neg(26.), 11., 28.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 8., 27.)',
#  'make_tuple(mul(neg(0.0029699264181608704), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), if_gt(26., mkd, xvar, 8.), 9., 27.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 22., 9., 30.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., 24.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 7., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 9., 25.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., 11., 30.)',
#  'make_tuple(mul(0.0033824366858742514, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 22., 11., 27.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 23., 9., 27.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 22., 9., 27.)',
#  'make_tuple(0.0015386973325914777, mul(22., 0.09099584414659372), 11., 28.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., expit(mul(9., xvar)), 27.)',
#  'make_tuple(pow(m, mul(0.0029699264181608704, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 40.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 97., 27.)',
#  'make_tuple(mul(0.003204049692044495, sub(mcp, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., expit(9.), 27.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 26., 9., 29.)',
#  'make_tuple(mul(0.0029699264181608704, mkd), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 22., 11., 30.)',
#  'make_tuple(0.0015386973325914777, 26., neg(11.), 30.)',
#  'make_tuple(mul(0.003271156143365597, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., min(29., 0.12064833224870987))',
#  'make_tuple(mul(min(0.0029714839486077085, 1.), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., mul(9., 0.03313793819956035), 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(10., 0.9043037255189352), 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 9., sub(xvar, 27.))',
#  'make_tuple(mul(0.0028841862760916426, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.1686916893570251, 0.0015386973325914777), 26., 11., 28.)',
#  'make_tuple(mul(0.0031978614174648545, xvar), 26., 9., 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 22., 11., 28.)',
#  'make_tuple(add(0.0029699264181608704, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, expit(mcp)), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., min(mkd, 29.))',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., sub(1., 27.))',
#  'make_tuple(mcp, 22., 11., 28.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(if_gt(n, xvar, rc, 10.), xvar), 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., pow(mkd, 28.))',
#  'make_tuple(xvar, 22., 11., 29.)',
#  'make_tuple(mul(0.002954589286502831, min(p, mcp)), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., min(xvar, 28.))',
#  'make_tuple(rc, 22., 11., 28.)',
#  'make_tuple(mul(0.003112216848324117, m), 26., 9., 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., 10., 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., neg(29.))',
#  'make_tuple(0.0015386973325914777, 26., neg(11.), 28.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 21., 9., 27.)',
#  'make_tuple(mul(min(0.0029714839486077085, 1.), mcp), 26., 11., 28.)',
#  'make_tuple(0.0015386973325914777, 22., max(rc, 11.), 28.)',
#  'make_tuple(mul(0.0015386973325914777, 0.2814488718769008), 22., 11., 28.)',
#  'make_tuple(mul(0.003204049692044495, mcp), 26., 9., pow(0.03322291568578227, 27.))',
#  'make_tuple(mul(0.003112216848324117, 0.10975668965330666), 26., 9., 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., mul(9., 0.047085900031135525), 27.)',
#  'make_tuple(mul(0.002994564689595089, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, mcp), pow(rc, 26.), 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 360., 27.)',
#  'make_tuple(pow(m, 0.0015386973325914777), 22., 11., 28.)',
#  'make_tuple(mul(0.0035526245440679035, mcp), 26., 9., 27.)',
#  'make_tuple(mul(min(0.0029714839486077085, 1.), mcp), 22., 11., 28.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 26., 9., 170.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 26., 7., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., expit(27.))',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 23.)',
#  'make_tuple(mul(rc, mul(0.003112216848324117, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(min(0.0029714839486077085, n), mcp), 26., 11., 28.)',
#  'make_tuple(mul(0.0031047362894301785, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., max(mkd, 9.), 27.)',
#  'make_tuple(sub(0.002954589286502831, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003112216848324117, expit(mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.003204049692044495, rc), 26., 9., 27.)',
#  'make_tuple(mul(0.0031144921019728242, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003112216848324117, rc), 26., 9., 27.)',
#  'make_tuple(xvar, 26., 11., 28.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 7., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 26., 11., truediv(xvar, 28.))',
#  'make_tuple(mul(0.002954589286502831, mcp), 30., 9., 27.)',
#  'make_tuple(max(0.003112216848324117, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., if_gt(mkd, 30., xvar, 6.))',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 342.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 26., 9., 23.)',
#  'make_tuple(mul(0.0031144921019728242, mcp), 26., 7., 27.)',
#  'make_tuple(mul(0.0030024822495714797, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003112216848324117, xvar), 26., 9., 27.)',
#  'make_tuple(mul(0.003112216848324117, min(0.004975243454659807, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.003112216848324117, neg(mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(9., 0.014632585768590502), 27.)',
#  'make_tuple(0.0015386973325914777, truediv(xvar, 22.), 11., 28.)',
#  'make_tuple(mul(neg(0.002954589286502831), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 25., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., min(9., xvar), 27.)',
#  'make_tuple(mul(0.003112216848324117, 0.24327313897616035), 26., 9., 27.)',
#  'make_tuple(min(m, 0.0015386973325914777), 22., 11., 29.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 240., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 11., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 538., 27.)',
#  'make_tuple(mul(0.002954589286502831, 0.007410959802029827), 26., 9., 27.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 718., 9., 27.)',
#  'make_tuple(add(0.0015386973325914777, mcp), 22., 11., 29.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 21., 9., 27.)',
#  'make_tuple(mul(add(mkd, 0.003112216848324117), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 63., 9., 27.)',
#  'make_tuple(mul(0.0031144921019728242, mcp), 22., 11., 27.)',
#  'make_tuple(mul(0.0031144921019728242, 0.009344389707633174), 26., 9., 27.)',
#  'make_tuple(mul(0.0031144921019728242, mcp), 30., 9., 27.)',
#  'make_tuple(max(mul(0.0031144921019728242, mcp), mkd), 26., 9., 27.)',
#  'make_tuple(expit(mul(0.002954589286502831, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.0033971578740144602, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0033158890246668894, mcp), 26., 9., 27.)',
#  'make_tuple(sub(0.003112216848324117, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 22., 11., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 22., 11., 27.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., 11., 27.)',
#  'make_tuple(mul(0.0031144921019728242, mcp), 32., 9., 27.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., sub(9., xvar), 27.)',
#  'make_tuple(mul(0.0031144921019728242, mcp), 26., 8., 27.)',
#  'make_tuple(mul(0.002957857641164909, mcp), 26., 9., 27.)',
#  'make_tuple(max(0.0031978614174648545, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., truediv(rc, 9.), 27.)',
#  'make_tuple(if_gt(0.0015386973325914777, 6., po, 595.), 22., 11., 28.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., add(9., xvar), 27.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 26., 11., 27.)',
#  'make_tuple(mul(0.0033899167488566266, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 22., neg(11.), 28.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 22., 11., 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., neg(30.))',
#  'make_tuple(mul(0.002954589286502831, expit(mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., mul(9., truediv(xvar, xvar)), 27.)',
#  'make_tuple(mul(m, 0.0015386973325914777), 22., 11., 29.)',
#  'make_tuple(mul(0.0031144921019728242, mcp), 89., 9., 27.)',
#  'make_tuple(max(rc, 0.0015386973325914777), 22., 11., 29.)',
#  'make_tuple(neg(0.0015386973325914777), 22., 11., 29.)',
#  'make_tuple(mul(0.003112216848324117, 0.005257301024620989), 26., 9., 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 26., 11., 29.)',
#  'make_tuple(mul(mcp, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, truediv(mkd, 22.), 11., 28.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(9., 0.47578267527978024), 27.)',
#  'make_tuple(mul(0.0031144921019728242, mcp), 194., 9., 27.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 26., 9., truediv(6., 27.))',
#  'make_tuple(mul(0.003112216848324117, mcp), 11., 9., 27.)',
#  'make_tuple(pow(0.002954589286502831, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0030905473920705123, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., if_gt(28., 0.07383411573943642, 0.011321847609604004, n))',
#  'make_tuple(mul(0.0029699264181608704, mcp), 26., mul(9., 0.2222976944985028), 27.)',
#  'make_tuple(mul(0.0031978614174648545, mcp), 23., 9., 27.)',
#  'make_tuple(mul(0.0031160482440797366, rc), 26., 9., 27.)',
#  'make_tuple(mul(rc, mul(0.0031978614174648545, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(9., 0.09005709353016557), 27.)',
#  'make_tuple(mul(0.0031144921019728242, mcp), 26., 9., 78.)',
#  'make_tuple(0.0015386973325914777, add(22., mcp), 11., 28.)',
#  'make_tuple(0.0015386973325914777, sub(mcp, 22.), 11., 30.)',
#  'make_tuple(mul(max(0.0031144921019728242, 0.03203690355683936), mcp), 26., 9., 27.)',
#  'make_tuple(0.0015386973325914777, 22., 11., add(28., xvar))',
#  'make_tuple(max(0.0015386973325914777, mcp), 22., 11., 29.)',
#  'make_tuple(mul(0.0029714839486077085, mcp), 26., truediv(xvar, mul(9., xvar)), 27.)',
# ...
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 9., 17.)',
#  'make_tuple(if_gt(mcp, mul(0.003161778087325457, mcp), mkd, m), 26., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 10., 17.)',
#  'make_tuple(mul(mul(0.002954589286502831, mcp), mcp), 22., 11., 28.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 25., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., mul(9., 0.23617349362070084), 17.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., max(xvar, 9.), 27.)',
#  'make_tuple(mul(0.003112216848324117, mcp), 26., 525., 27.)',
#  'make_tuple(mul(max(0.0031160482440797366, mkd), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., max(9., xvar), 17.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 9., 24.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 11., 28.)',
#  'make_tuple(0.0015582444787414023, 22., 11., max(xvar, 30.))',
#  'make_tuple(mul(expit(0.003161778087325457), mcp), 26., 9., 27.)',
#  'make_tuple(if_gt(0.0015582444787414023, mcp, p, 821.), 22., 11., 30.)',
#  'make_tuple(truediv(0.0015386973325914777, n), 22., 11., 28.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 8., 27.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 25., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 22., neg(11.), 30.)',
#  'make_tuple(mul(mul(0.002954589286502831, mcp), mcp), 26., 11., 30.)',
#  'make_tuple(0.0015582444787414023, 26., pow(11., 0.029753031880434377), 30.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 58., 9., 27.)',
#  'make_tuple(mul(0.0031160482440797366, 0.011956328414245333), 25., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., mul(9., 0.006414457342440783), 17.)',
#  'make_tuple(0.0015582444787414023, 22., 11., add(30., mcp))',
#  'make_tuple(mul(0.0030471628549466876, mcp), 26., 9., 27.)',
#  'make_tuple(add(0.0031160482440797366, mcp), 25., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., sub(9., xvar), 17.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 9., 19.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 148., 9., 27.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 20., 9., 30.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(9., 0.27729559137257775), 17.)',
#  'make_tuple(max(0.0031160482440797366, mcp), 25., 9., 27.)',
#  'make_tuple(xvar, 26., 11., 30.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 25., 9., 17.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 25., 9., 3.)',
#  'make_tuple(rc, 20., 11., 30.)',
#  'make_tuple(mul(0.025739471677184888, mcp), 26., 9., 27.)',
#  'make_tuple(max(34., mul(0.0031160482440797366, mcp)), 26., 9., 27.)',
#  'make_tuple(xvar, 22., 11., 30.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., mul(truediv(6., 9.), xvar), 17.)',
#  'make_tuple(truediv(0.003161778087325457, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(expit(9.), xvar), 17.)',
#  'make_tuple(0.0015582444787414023, 26., 11., pow(mkd, 30.))',
#  'make_tuple(0.0015582444787414023, min(0.25776645582487845, 22.), 11., 30.)',
#  'make_tuple(mul(pow(0.003161778087325457, mkd), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, 0.08553539881753872), 26., 9., 27.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 27., 9., 27.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 9., 30.)',
#  'make_tuple(0.0015582444787414023, 22., pow(0.2854258032834596, 11.), 30.)',
#  'make_tuple(0.0015582444787414023, 26., 11., neg(30.))',
#  'make_tuple(mul(0.0031160482440797366, mcp), 2., 9., 27.)',
#  'make_tuple(0.0015582444787414023, min(26., mkd), 11., 29.)',
#  'make_tuple(mcp, 22., 11., 30.)',
#  'make_tuple(mul(mul(0.002954589286502831, mcp), mcp), 26., mul(9., 0.11100771772459016), 17.)',
#  'make_tuple(min(rc, 0.0015582444787414023), 22., 11., 30.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., add(9., xvar), 17.)',
#  'make_tuple(0.0015582444787414023, 26., 11., mul(29., 142.))',
#  'make_tuple(mul(0.0030917168556055274, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 22., 11., min(30., 0.10690688531517287))',
#  'make_tuple(neg(0.0015582444787414023), 22., 11., 30.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(9., 0.4181965292201315), 17.)',
#  'make_tuple(mul(0.6107388326153064, mcp), 26., 9., 27.)',
#  'make_tuple(mul(mul(0.002954589286502831, mcp), mcp), 26., mul(9., 0.014880742165183796), 17.)',
#  'make_tuple(neg(mul(0.003161778087325457, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, max(rc, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.0015582444787414023, m), 26., 11., 29.)',
#  'make_tuple(mul(0.021180591111044502, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 11., 29.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), pow(rc, 26.), 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 11., 17.)',
#  'make_tuple(pow(0.003161778087325457, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 26., 11., max(30., mkd))',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 9., 456.)',
#  'make_tuple(mul(0.0031160482440797366, 0.0036465706872503786), 26., 9., 27.)',
#  'make_tuple(mul(mul(0.002954589286502831, mcp), mcp), 26., mul(9., 0.04092442429600598), 17.)',
#  'make_tuple(mul(mul(0.002954589286502831, mcp), mcp), 26., 9., 17.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 23., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), min(26., rc), 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 9., 91.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 2., 9., 27.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 9., 17.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 9., 9.)',
#  'make_tuple(mul(mul(0.002954589286502831, mcp), mcp), pow(n, 26.), mul(9., xvar), 17.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 10., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 17.)',
#  'make_tuple(mul(0.002954589286502831, mcp), pow(26., n), mul(9., xvar), mul(mcp, 34.))',
#  'make_tuple(mul(0.5419675130624296, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(9., 0.615344707290093), 17.)',
#  'make_tuple(0.0015582444787414023, neg(23.), 11., 30.)',
#  'make_tuple(mul(mul(0.002954589286502831, mcp), mcp), 22., 11., 30.)',
#  'make_tuple(0.0015582444787414023, 22., 11., max(30., rc))',
#  'make_tuple(truediv(0.0031160482440797366, mcp), 26., 9., 27.)',
#  'make_tuple(add(0.002963023812113917, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.003161778087325457, mkd), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 27., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 26., 11., truediv(xvar, 30.))',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., min(xvar, mcp), 17.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 9., 55.)',
#  'make_tuple(mul(0.003161778087325457, add(rc, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 10., 27.)',
#  'make_tuple(mul(0.0069773358935437315, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., pow(9., 0.48649229681020023), 27.)',
#  'make_tuple(mul(0.0031160482440797366, min(mcp, m)), 26., 9., 27.)',
#  'make_tuple(mul(0.002396325952173741, mcp), 26., 9., 28.)',
#  'make_tuple(mul(min(0.003161778087325457, xvar), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 9., 31.)',
#  'make_tuple(pow(0.0019248252365235365, mul(0.003161778087325457, mcp)), 26., 9., 28.)',
#  'make_tuple(mul(0.0031160482440797366, neg(mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 9., 22.)',
#  'make_tuple(mul(0.0031160482440797366, 0.11298055819176703), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 28., 9., 27.)',
#  'make_tuple(mul(if_gt(0.054328227716790994, m, 0.1860205957645084, 0.003161778087325457), mcp), 26., 9., 28.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 9., expit(27.))',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 10., 28.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 7., 27.)',
#  'make_tuple(mul(0.0031160482440797366, sub(mcp, 0.047955721843589046)), 26., 9., 27.)',
#  'make_tuple(0.0015582444787414023, pow(n, 26.), 11., 30.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 9., 17.)',
#  'make_tuple(mul(mul(0.003624493853971778, mcp), mcp), 26., 9., 17.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 4., 28.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., add(27., mkd))',
#  'make_tuple(mul(0.003161778087325457, mcp), 22., 11., 30.)',
#  'make_tuple(mul(mul(0.0032569767108165683, mcp), mcp), 26., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 22., 11., if_gt(30., 0.888808223942307, 34., rc))',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 74., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 9., 25.)',
#  'make_tuple(mul(mul(0.0032569767108165683, mcp), mcp), 26., 9., 17.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 18., 9., 27.)',
#  'make_tuple(mul(mul(0.003602608190069447, mcp), mcp), 26., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 21., min(rc, 11.), 30.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 56., 27.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 9., truediv(mcp, 27.))',
#  'make_tuple(rc, 21., 11., 30.)',
#  'make_tuple(0.0015582444787414023, add(22., rc), 11., 30.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 9., 20.)',
#  'make_tuple(add(0.004713131489015139, mul(0.003161778087325457, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(mul(0.0032569767108165683, mcp), mcp), 26., min(xvar, mcp), 17.)',
#  'make_tuple(mul(mul(0.003395854880352856, mcp), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 9., 18.)',
#  'make_tuple(mul(pow(m, 0.002954589286502831), mcp), 26., 9., 27.)',
#  'make_tuple(mul(mul(0.0034635445762518586, mcp), mcp), 26., 11., 30.)',
#  'make_tuple(mul(mul(0.0032569767108165683, mcp), mcp), 26., mul(9., 0.004938702272132051), 17.)',
#  'make_tuple(mul(mul(0.003395854880352856, mcp), mcp), 26., 9., 17.)',
#  'make_tuple(mul(0.002954589286502831, rc), 26., 9., 27.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 9., 1.)',
#  'make_tuple(mul(mul(0.0032569767108165683, mcp), mcp), 26., 11., 17.)',
#  'make_tuple(0.0015582444787414023, 21., 11., if_gt(xvar, 30., mcp, xvar))',
#  'make_tuple(mul(pow(0.003161778087325457, p), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0030586051588851627, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 9., 28.)',
#  'make_tuple(0.0015582444787414023, pow(22., 462.), 11., 30.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., min(11., min(xvar, mcp)), 27.)',
#  'make_tuple(mul(0.003612613459737084, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 22., 11., 17.)',
#  'make_tuple(0.0015582444787414023, 22., 11., pow(mkd, 30.))',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 8., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 11., 27.)',
#  'make_tuple(0.0015582444787414023, neg(21.), 11., 30.)',
#  'make_tuple(mul(0.0035543662474195443, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 9., 26.)',
#  'make_tuple(mul(0.003161778087325457, sub(0.03862953604889326, mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(truediv(xvar, 9.), xvar), 17.)',
#  'make_tuple(mul(mul(0.003602608190069447, mcp), mcp), 26., 11., 30.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 9., 30.)',
#  'make_tuple(0.0015582444787414023, 22., add(11., mcp), 30.)',
#  'make_tuple(mul(0.02116903791142771, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., min(10., min(xvar, mcp)), 17.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., sub(9., xvar), 17.)',
#  'make_tuple(truediv(0.0031601072833283843, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., min(xvar, mcp), 17.)',
#  'make_tuple(mul(mul(0.003395854880352856, mcp), mcp), 22., 11., 30.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 11., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 26., 9., expit(27.))',
#  'make_tuple(mul(0.0031601072833283843, mkd), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(9., 0.09687595318390359), 17.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 11., 30.)',
#  'make_tuple(0.0015582444787414023, 26., neg(11.), 30.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 1., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 19., 11., 30.)',
#  'make_tuple(mul(0.002837842676448381, mcp), 26., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 26., 11., mul(0.0037166066921101044, 30.))',
#  'make_tuple(mul(0.0032628920841107183, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031601072833283843, 0.0014318921018925078), 26., 9., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., 11., 17.)',
#  'make_tuple(max(390., 0.0015582444787414023), 19., 11., 30.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(11., min(xvar, 0.1598362256715509)), 17.)',
#  'make_tuple(mkd, 26., 11., 30.)',
#  'make_tuple(mul(mul(0.003395854880352856, mcp), mcp), 26., min(12., min(xvar, mcp)), 17.)',
#  'make_tuple(mul(0.0031601072833283843, 0.04871527869265823), 26., 9., 27.)',
#  'make_tuple(pow(mul(0.003161778087325457, mcp), m), 26., 9., 27.)',
#  'make_tuple(mul(0.0031601072833283843, neg(mcp)), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(11., min(xvar, 0.03277333607761922)), 17.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., mul(12., min(0.0032044088547457795, mcp)), 17.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., 12., 17.)',
#  'make_tuple(mul(0.0031601072833283843, m), 26., 9., 27.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 3., 9., 27.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 9., 17.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 638., 27.)',
#  'make_tuple(mul(mul(0.003395854880352856, mcp), mcp), 26., 12., 17.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(12., mul(0.002132488744820496, min(xvar, mcp))), 17.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., mul(if_gt(9., 2., xvar, m), xvar), 17.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 9., 2.)',
#  'make_tuple(mul(0.003161778087325457, mcp), 24., 9., 27.)',
#  'make_tuple(mul(0.0031160482440797366, if_gt(m, mkd, xvar, mcp)), 26., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 26., 11., pow(mcp, 28.))',
#  'make_tuple(0.0015582444787414023, 26., 11., mul(41., 28.))',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 10., 27.)',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., min(13., min(xvar, mcp)), 17.)',
#  'make_tuple(0.0015582444787414023, 22., pow(mcp, 11.), 30.)',
#  'make_tuple(mul(neg(0.0031601072833283843), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 28., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 25., 11., mul(30., 6.))',
#  'make_tuple(pow(0.0031601072833283843, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 7., 9., 27.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 26., 9., 557.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., truediv(mul(12., min(xvar, mcp)), 483.), 17.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 330., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 22., 11., neg(30.))',
#  'make_tuple(0.0015582444787414023, 26., 11., pow(mcp, 30.))',
#  'make_tuple(mul(0.002963023812113917, mcp), 26., mul(truediv(rc, 13.), mcp), 17.)',
#  'make_tuple(mul(mul(0.003343531811159645, mcp), mcp), 26., 9., 27.)',
#  'make_tuple(0.0015582444787414023, 22., 11., min(mcp, 30.))',
#  'make_tuple(mul(mul(0.003471262333739982, mcp), mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.002954589286502831, mcp), 26., mul(13., min(0.004154938739042118, mcp)), 17.)',
#  'make_tuple(mul(0.40367637126558786, mcp), 26., 9., 27.)',
#  'make_tuple(mul(0.0031601072833283843, mcp), 22., 9., 27.)',
#  'make_tuple(mul(mul(0.003343531811159645, mcp), mcp), 26., 11., 30.)',
#  'make_tuple(mul(0.0031160482440797366, mcp), 26., 9., 150.)',
#  'make_tuple(0.0015481093312916718, 26., sub(mcp, 11.), 30.)',
#  ...]
